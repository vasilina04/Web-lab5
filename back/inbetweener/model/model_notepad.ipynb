# %%
import os
import json
import datetime as dt
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 10]
plt.rcParams['font.size'] = 14

import seaborn as sns
import cv2
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.metrics import categorical_accuracy, top_k_categorical_accuracy, categorical_crossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import MobileNet
from tensorflow.keras.applications.mobilenet import preprocess_input

# %%
DP_DIR = '../input/shuffle-csvs/'
INPUT_DIR = '../input/quickdraw-doodle-recognition/'

BASE_SIZE = 256
NCSVS = 100
NCATS = 340
np.random.seed(seed=1987)
tf.set_random_seed(seed=1987)

def f2cat(filename: str) -> str:
    return filename.split('.')[0]

def list_all_categories():
    files = os.listdir(os.path.join(INPUT_DIR, 'train_simplified'))
    return sorted([f2cat(f) for f in files], key=str.lower)

# %%
def apk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    if len(predicted) > k:
        predicted = predicted[:k]
    score = 0.0
    num_hits = 0.0
    for i, p in enumerate(predicted):
        if p in actual and p not in predicted[:i]:
            num_hits += 1.0
            score += num_hits / (i + 1.0)
    if not actual:
        return 0.0
    return score / min(len(actual), k)

def mapk(actual, predicted, k=3):
    """
    Source: https://github.com/benhamner/Metrics/blob/master/Python/ml_metrics/average_precision.py
    """
    return np.mean([apk(a, p, k) for a, p in zip(actual, predicted)])

def preds2catids(predictions):
    return pd.DataFrame(np.argsort(-predictions, axis=1)[:, :3], columns=['a', 'b', 'c'])

def top_3_accuracy(y_true, y_pred):
    return top_k_categorical_accuracy(y_true, y_pred, k=3)

# %%
STEPS = 800
EPOCHS = 16
size = 64
batchsize = 680

# %%
model = MobileNet(input_shape=(size, size, 1), alpha=1., weights=None, classes=NCATS)
model.compile(optimizer=Adam(lr=0.002), loss='categorical_crossentropy',
              metrics=[categorical_crossentropy, categorical_accuracy, top_3_accuracy])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 1)         0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 65, 65, 1)         0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 32, 32, 32)        288
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 32, 32, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 32, 32, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 32, 32, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 32, 32, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 32, 32, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 32, 32, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 32, 32, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 33, 33, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 16, 16, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 16, 16, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 16, 16, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 16, 16, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 16, 16, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 16, 16, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 16, 16, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 17, 17, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 8, 8, 128)         1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 8, 8, 128)         512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 8, 8, 256)         32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 8, 8, 256)         2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 8, 8, 256)         65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 8, 8, 256)         1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 9, 9, 256)         0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 4, 4, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 4, 4, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 4, 4, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 4, 4, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 4, 4, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 4, 4, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 4, 4, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 5, 5, 512)         0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 2, 2, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 2, 2, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 2, 2, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 2, 2, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 2, 2, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 2, 2, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 2, 2, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_preds (Conv2D)          (None, 1, 1, 340)         348500
# _________________________________________________________________
# act_softmax (Activation)     (None, 1, 1, 340)         0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 340)               0
# =================================================================
# Total params: 3,576,788
# Trainable params: 3,554,900
# Non-trainable params: 21,888
# _________________________________________________________________
# None

# %% [markdown]
# ## Training with Image Generator

# %%
def draw_cv2(raw_strokes, size=256, lw=6, time_color=True):
    img = np.zeros((BASE_SIZE, BASE_SIZE), np.uint8)
    for t, stroke in enumerate(raw_strokes):
        for i in range(len(stroke[0]) - 1):
            color = 255 - min(t, 10) * 13 if time_color else 255
            _ = cv2.line(img, (stroke[0][i], stroke[1][i]),
                         (stroke[0][i + 1], stroke[1][i + 1]), color, lw)
    if size != BASE_SIZE:
        return cv2.resize(img, (size, size))
    else:
        return img

def image_generator_xd(size, batchsize, ks, lw=6, time_color=True):
    while True:
        for k in np.random.permutation(ks):
            filename = os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(k))
            for df in pd.read_csv(filename, chunksize=batchsize):
                df['drawing'] = df['drawing'].apply(json.loads)
                x = np.zeros((len(df), size, size, 1))
                for i, raw_strokes in enumerate(df.drawing.values):
                    x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw,
                                             time_color=time_color)
                x = preprocess_input(x).astype(np.float32)
                y = keras.utils.to_categorical(df.y, num_classes=NCATS)
                yield x, y

def df_to_image_array_xd(df, size, lw=6, time_color=True):
    df['drawing'] = df['drawing'].apply(json.loads)
    x = np.zeros((len(df), size, size, 1))
    for i, raw_strokes in enumerate(df.drawing.values):
        x[i, :, :, 0] = draw_cv2(raw_strokes, size=size, lw=lw, time_color=time_color)
    x = preprocess_input(x).astype(np.float32)
    return x

# %%
valid_df = pd.read_csv(os.path.join(DP_DIR, 'train_k{}.csv.gz'.format(NCSVS - 1)), nrows=34000)
x_valid = df_to_image_array_xd(valid_df, size)
y_valid = keras.utils.to_categorical(valid_df.y, num_classes=NCATS)
print(x_valid.shape, y_valid.shape)
print('Validation array memory {:.2f} GB'.format(x_valid.nbytes / 1024.**3 ))
# Out:
# (34000, 64, 64, 1) (34000, 340)
# Validation array memory 0.52 GB

# %%
train_datagen = image_generator_xd(size=size, batchsize=batchsize, ks=range(NCSVS - 1))

# %%
x, y = next(train_datagen)
n = 8
fig, axs = plt.subplots(nrows=n, ncols=n, sharex=True, sharey=True, figsize=(12, 12))
for i in range(n**2):
    ax = axs[i // n, i % n]
    ax.imshow((-x[i, :, :, 0] + 1)/2, cmap=plt.cm.gray)
    ax.axis('off')
plt.tight_layout()
fig.savefig('gs.png', dpi=300)
plt.show();

# %%
# %%timeit
x, y = next(train_datagen)
# Out:
# 127 ms ± 1.29 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
callbacks = [
    ReduceLROnPlateau(monitor='val_top_3_accuracy', factor=0.75, patience=3, min_delta=0.001,
                          mode='max', min_lr=1e-5, verbose=1),
    ModelCheckpoint('model.h5', monitor='val_top_3_accuracy', mode='max', save_best_only=True,
                    save_weights_only=True),
]
hists = []
hist = model.fit_generator(
    train_datagen, steps_per_epoch=STEPS, epochs=70, verbose=1,
    validation_data=(x_valid, y_valid),
    callbacks = callbacks
)
hists.append(hist)
# Out:
# Epoch 1/70
# 800/800 [==============================] - 166s 208ms/step - loss: 2.8490 - categorical_crossentropy: 2.8490 - categorical_accuracy: 0.3646 - top_3_accuracy: 0.5492 - val_loss: 2.6728 - val_categorical_crossentropy: 2.6728 - val_categorical_accuracy: 0.4140 - val_top_3_accuracy: 0.6306
# Epoch 2/70
# 800/800 [==============================] - 148s 185ms/step - loss: 1.6764 - categorical_crossentropy: 1.6764 - categorical_accuracy: 0.5856 - top_3_accuracy: 0.7829 - val_loss: 2.0886 - val_categorical_crossentropy: 2.0886 - val_categorical_accuracy: 0.5094 - val_top_3_accuracy: 0.7226
# Epoch 3/70
# 800/800 [==============================] - 149s 186ms/step - loss: 1.4573 - categorical_crossentropy: 1.4573 - categorical_accuracy: 0.6341 - top_3_accuracy: 0.8209 - val_loss: 1.8116 - val_categorical_crossentropy: 1.8116 - val_categorical_accuracy: 0.5601 - val_top_3_accuracy: 0.7650
# Epoch 4/70
# 800/800 [==============================] - 148s 185ms/step - loss: 1.3385 - categorical_crossentropy: 1.3385 - categorical_accuracy: 0.6625 - top_3_accuracy: 0.8417 - val_loss: 1.5904 - val_categorical_crossentropy: 1.5904 - val_categorical_accuracy: 0.6054 - val_top_3_accuracy: 0.8033
# Epoch 5/70
# 800/800 [==============================] - 147s 183ms/step - loss: 1.3103 - categorical_crossentropy: 1.3103 - categorical_accuracy: 0.6691 - top_3_accuracy: 0.8452 - val_loss: 3.7922 - val_categorical_crossentropy: 3.7922 - val_categorical_accuracy: 0.2513 - val_top_3_accuracy: 0.4331
# Epoch 6/70
# 800/800 [==============================] - 150s 187ms/step - loss: 1.2174 - categorical_crossentropy: 1.2174 - categorical_accuracy: 0.6906 - top_3_accuracy: 0.8606 - val_loss: 1.3130 - val_categorical_crossentropy: 1.3130 - val_categorical_accuracy: 0.6649 - val_top_3_accuracy: 0.8454
# Epoch 7/70
# 800/800 [==============================] - 147s 183ms/step - loss: 1.1718 - categorical_crossentropy: 1.1718 - categorical_accuracy: 0.7010 - top_3_accuracy: 0.8676 - val_loss: 3.0982 - val_categorical_crossentropy: 3.0982 - val_categorical_accuracy: 0.3436 - val_top_3_accuracy: 0.5471
# Epoch 8/70
# 800/800 [==============================] - 149s 186ms/step - loss: 1.1449 - categorical_crossentropy: 1.1449 - categorical_accuracy: 0.7076 - top_3_accuracy: 0.8716 - val_loss: 2.5391 - val_categorical_crossentropy: 2.5391 - val_categorical_accuracy: 0.4256 - val_top_3_accuracy: 0.6350
# Epoch 9/70
# 799/800 [============================>.] - ETA: 0s - loss: 1.1445 - categorical_crossentropy: 1.1445 - categorical_accuracy: 0.7082 - top_3_accuracy: 0.8712
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.001500000071246177.
# 800/800 [==============================] - 148s 185ms/step - loss: 1.1444 - categorical_crossentropy: 1.1444 - categorical_accuracy: 0.7082 - top_3_accuracy: 0.8712 - val_loss: 1.4202 - val_categorical_crossentropy: 1.4202 - val_categorical_accuracy: 0.6430 - val_top_3_accuracy: 0.8262
# Epoch 10/70
# 800/800 [==============================] - 148s 185ms/step - loss: 1.0693 - categorical_crossentropy: 1.0693 - categorical_accuracy: 0.7268 - top_3_accuracy: 0.8827 - val_loss: 1.0869 - val_categorical_crossentropy: 1.0869 - val_categorical_accuracy: 0.7218 - val_top_3_accuracy: 0.8817
# Epoch 11/70
# 800/800 [==============================] - 148s 185ms/step - loss: 1.0370 - categorical_crossentropy: 1.0370 - categorical_accuracy: 0.7341 - top_3_accuracy: 0.8871 - val_loss: 1.1280 - val_categorical_crossentropy: 1.1280 - val_categorical_accuracy: 0.7127 - val_top_3_accuracy: 0.8744
# Epoch 13/70
# 800/800 [==============================] - 148s 185ms/step - loss: 1.0287 - categorical_crossentropy: 1.0287 - categorical_accuracy: 0.7368 - top_3_accuracy: 0.8884 - val_loss: 1.0508 - val_categorical_crossentropy: 1.0508 - val_categorical_accuracy: 0.7313 - val_top_3_accuracy: 0.8856
# Epoch 14/70
# 800/800 [==============================] - 148s 185ms/step - loss: 1.0116 - categorical_crossentropy: 1.0116 - categorical_accuracy: 0.7399 - top_3_accuracy: 0.8908 - val_loss: 1.0247 - val_categorical_crossentropy: 1.0247 - val_categorical_accuracy: 0.7371 - val_top_3_accuracy: 0.8904
# Epoch 15/70
# 800/800 [==============================] - 150s 187ms/step - loss: 0.9962 - categorical_crossentropy: 0.9962 - categorical_accuracy: 0.7433 - top_3_accuracy: 0.8932 - val_loss: 1.0236 - val_categorical_crossentropy: 1.0236 - val_categorical_accuracy: 0.7386 - val_top_3_accuracy: 0.8901
# Epoch 16/70
# 800/800 [==============================] - 146s 183ms/step - loss: 1.0110 - categorical_crossentropy: 1.0110 - categorical_accuracy: 0.7406 - top_3_accuracy: 0.8905 - val_loss: 1.0291 - val_categorical_crossentropy: 1.0291 - val_categorical_accuracy: 0.7379 - val_top_3_accuracy: 0.8877
# Epoch 17/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.9840 - categorical_crossentropy: 0.9840 - categorical_accuracy: 0.7466 - top_3_accuracy: 0.8948
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.001125000009778887.
# 800/800 [==============================] - 149s 186ms/step - loss: 0.9840 - categorical_crossentropy: 0.9840 - categorical_accuracy: 0.7466 - top_3_accuracy: 0.8948 - val_loss: 1.0163 - val_categorical_crossentropy: 1.0163 - val_categorical_accuracy: 0.7397 - val_top_3_accuracy: 0.8912
# Epoch 18/70
# 800/800 [==============================] - 150s 188ms/step - loss: 0.9518 - categorical_crossentropy: 0.9518 - categorical_accuracy: 0.7550 - top_3_accuracy: 0.8994 - val_loss: 0.9590 - val_categorical_crossentropy: 0.9590 - val_categorical_accuracy: 0.7556 - val_top_3_accuracy: 0.8980
# Epoch 19/70
# 800/800 [==============================] - 147s 184ms/step - loss: 0.9312 - categorical_crossentropy: 0.9312 - categorical_accuracy: 0.7599 - top_3_accuracy: 0.9019 - val_loss: 0.9656 - val_categorical_crossentropy: 0.9656 - val_categorical_accuracy: 0.7532 - val_top_3_accuracy: 0.8987
# Epoch 20/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.9175 - categorical_crossentropy: 0.9175 - categorical_accuracy: 0.7622 - top_3_accuracy: 0.9043 - val_loss: 0.9813 - val_categorical_crossentropy: 0.9813 - val_categorical_accuracy: 0.7484 - val_top_3_accuracy: 0.8943
# Epoch 21/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.9111 - categorical_crossentropy: 0.9111 - categorical_accuracy: 0.7640 - top_3_accuracy: 0.9050
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0008437499636784196.
# 800/800 [==============================] - 145s 182ms/step - loss: 0.9112 - categorical_crossentropy: 0.9112 - categorical_accuracy: 0.7640 - top_3_accuracy: 0.9050 - val_loss: 0.9554 - val_categorical_crossentropy: 0.9554 - val_categorical_accuracy: 0.7563 - val_top_3_accuracy: 0.8987
# Epoch 22/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8932 - categorical_crossentropy: 0.8932 - categorical_accuracy: 0.7684 - top_3_accuracy: 0.9074 - val_loss: 0.9212 - val_categorical_crossentropy: 0.9212 - val_categorical_accuracy: 0.7632 - val_top_3_accuracy: 0.9046
# Epoch 23/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.9041 - categorical_crossentropy: 0.9041 - categorical_accuracy: 0.7673 - top_3_accuracy: 0.9060 - val_loss: 0.9210 - val_categorical_crossentropy: 0.9210 - val_categorical_accuracy: 0.7649 - val_top_3_accuracy: 0.9042
# Epoch 24/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8800 - categorical_crossentropy: 0.8800 - categorical_accuracy: 0.7722 - top_3_accuracy: 0.9089 - val_loss: 0.9149 - val_categorical_crossentropy: 0.9149 - val_categorical_accuracy: 0.7669 - val_top_3_accuracy: 0.9044
# Epoch 25/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.8871 - categorical_crossentropy: 0.8871 - categorical_accuracy: 0.7710 - top_3_accuracy: 0.9077
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0006328124727588147.
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8872 - categorical_crossentropy: 0.8872 - categorical_accuracy: 0.7710 - top_3_accuracy: 0.9077 - val_loss: 0.9077 - val_categorical_crossentropy: 0.9077 - val_categorical_accuracy: 0.7693 - val_top_3_accuracy: 0.9054
# Epoch 26/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8641 - categorical_crossentropy: 0.8641 - categorical_accuracy: 0.7760 - top_3_accuracy: 0.9109 - val_loss: 0.8883 - val_categorical_crossentropy: 0.8883 - val_categorical_accuracy: 0.7754 - val_top_3_accuracy: 0.9077
# Epoch 27/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8637 - categorical_crossentropy: 0.8637 - categorical_accuracy: 0.7759 - top_3_accuracy: 0.9118 - val_loss: 0.8904 - val_categorical_crossentropy: 0.8904 - val_categorical_accuracy: 0.7726 - val_top_3_accuracy: 0.9089
# Epoch 28/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.8762 - categorical_crossentropy: 0.8762 - categorical_accuracy: 0.7734 - top_3_accuracy: 0.9097 - val_loss: 0.8867 - val_categorical_crossentropy: 0.8867 - val_categorical_accuracy: 0.7734 - val_top_3_accuracy: 0.9083
# Epoch 29/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8632 - categorical_crossentropy: 0.8632 - categorical_accuracy: 0.7767 - top_3_accuracy: 0.9111 - val_loss: 0.8838 - val_categorical_crossentropy: 0.8838 - val_categorical_accuracy: 0.7739 - val_top_3_accuracy: 0.9081
# Epoch 30/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8457 - categorical_crossentropy: 0.8457 - categorical_accuracy: 0.7799 - top_3_accuracy: 0.9134 - val_loss: 0.8781 - val_categorical_crossentropy: 0.8781 - val_categorical_accuracy: 0.7753 - val_top_3_accuracy: 0.9100
# Epoch 31/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8470 - categorical_crossentropy: 0.8470 - categorical_accuracy: 0.7805 - top_3_accuracy: 0.9129 - val_loss: 0.8737 - val_categorical_crossentropy: 0.8737 - val_categorical_accuracy: 0.7762 - val_top_3_accuracy: 0.9111
# Epoch 32/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.8515 - categorical_crossentropy: 0.8515 - categorical_accuracy: 0.7790 - top_3_accuracy: 0.9130 - val_loss: 0.8768 - val_categorical_crossentropy: 0.8768 - val_categorical_accuracy: 0.7763 - val_top_3_accuracy: 0.9088
# Epoch 33/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8613 - categorical_crossentropy: 0.8613 - categorical_accuracy: 0.7777 - top_3_accuracy: 0.9116 - val_loss: 0.8740 - val_categorical_crossentropy: 0.8740 - val_categorical_accuracy: 0.7761 - val_top_3_accuracy: 0.9098
# Epoch 34/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.8488 - categorical_crossentropy: 0.8488 - categorical_accuracy: 0.7800 - top_3_accuracy: 0.9130
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 0.00047460937639698386.
# 800/800 [==============================] - 145s 182ms/step - loss: 0.8491 - categorical_crossentropy: 0.8491 - categorical_accuracy: 0.7800 - top_3_accuracy: 0.9130 - val_loss: 0.8735 - val_categorical_crossentropy: 0.8735 - val_categorical_accuracy: 0.7766 - val_top_3_accuracy: 0.9099
# Epoch 35/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8409 - categorical_crossentropy: 0.8409 - categorical_accuracy: 0.7810 - top_3_accuracy: 0.9141 - val_loss: 0.8582 - val_categorical_crossentropy: 0.8582 - val_categorical_accuracy: 0.7793 - val_top_3_accuracy: 0.9108
# Epoch 36/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8288 - categorical_crossentropy: 0.8288 - categorical_accuracy: 0.7839 - top_3_accuracy: 0.9157 - val_loss: 0.8569 - val_categorical_crossentropy: 0.8569 - val_categorical_accuracy: 0.7806 - val_top_3_accuracy: 0.9124
# Epoch 37/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.8442 - categorical_crossentropy: 0.8442 - categorical_accuracy: 0.7818 - top_3_accuracy: 0.9135 - val_loss: 0.8527 - val_categorical_crossentropy: 0.8527 - val_categorical_accuracy: 0.7819 - val_top_3_accuracy: 0.9123
# Epoch 38/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.8004 - categorical_crossentropy: 0.8004 - categorical_accuracy: 0.7914 - top_3_accuracy: 0.9193 - val_loss: 0.8488 - val_categorical_crossentropy: 0.8488 - val_categorical_accuracy: 0.7825 - val_top_3_accuracy: 0.9137
# Epoch 39/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7906 - categorical_crossentropy: 0.7906 - categorical_accuracy: 0.7931 - top_3_accuracy: 0.9202 - val_loss: 0.8558 - val_categorical_crossentropy: 0.8558 - val_categorical_accuracy: 0.7798 - val_top_3_accuracy: 0.9111
# Epoch 40/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7883 - categorical_crossentropy: 0.7883 - categorical_accuracy: 0.7936 - top_3_accuracy: 0.9209 - val_loss: 0.8583 - val_categorical_crossentropy: 0.8583 - val_categorical_accuracy: 0.7805 - val_top_3_accuracy: 0.9124
# Epoch 41/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7993 - categorical_crossentropy: 0.7993 - categorical_accuracy: 0.7916 - top_3_accuracy: 0.9195
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0003559570322977379.
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7993 - categorical_crossentropy: 0.7993 - categorical_accuracy: 0.7916 - top_3_accuracy: 0.9195 - val_loss: 0.8549 - val_categorical_crossentropy: 0.8549 - val_categorical_accuracy: 0.7819 - val_top_3_accuracy: 0.9127
# Epoch 42/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7875 - categorical_crossentropy: 0.7875 - categorical_accuracy: 0.7948 - top_3_accuracy: 0.9207 - val_loss: 0.8449 - val_categorical_crossentropy: 0.8449 - val_categorical_accuracy: 0.7831 - val_top_3_accuracy: 0.9131
# Epoch 43/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7957 - categorical_crossentropy: 0.7957 - categorical_accuracy: 0.7930 - top_3_accuracy: 0.9195 - val_loss: 0.8469 - val_categorical_crossentropy: 0.8469 - val_categorical_accuracy: 0.7822 - val_top_3_accuracy: 0.9138
# Epoch 44/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7791 - categorical_crossentropy: 0.7791 - categorical_accuracy: 0.7963 - top_3_accuracy: 0.9217
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.000266967763309367.
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7790 - categorical_crossentropy: 0.7790 - categorical_accuracy: 0.7963 - top_3_accuracy: 0.9217 - val_loss: 0.8387 - val_categorical_crossentropy: 0.8387 - val_categorical_accuracy: 0.7850 - val_top_3_accuracy: 0.9143
# Epoch 45/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7804 - categorical_crossentropy: 0.7804 - categorical_accuracy: 0.7965 - top_3_accuracy: 0.9218 - val_loss: 0.8299 - val_categorical_crossentropy: 0.8299 - val_categorical_accuracy: 0.7879 - val_top_3_accuracy: 0.9158
# Epoch 46/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7825 - categorical_crossentropy: 0.7825 - categorical_accuracy: 0.7963 - top_3_accuracy: 0.9212 - val_loss: 0.8307 - val_categorical_crossentropy: 0.8307 - val_categorical_accuracy: 0.7879 - val_top_3_accuracy: 0.9150
# Epoch 47/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7755 - categorical_crossentropy: 0.7755 - categorical_accuracy: 0.7969 - top_3_accuracy: 0.9225 - val_loss: 0.8309 - val_categorical_crossentropy: 0.8309 - val_categorical_accuracy: 0.7883 - val_top_3_accuracy: 0.9152
# Epoch 48/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7868 - categorical_crossentropy: 0.7868 - categorical_accuracy: 0.7947 - top_3_accuracy: 0.9211
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 0.00020022581156808883.
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7868 - categorical_crossentropy: 0.7868 - categorical_accuracy: 0.7946 - top_3_accuracy: 0.9211 - val_loss: 0.8275 - val_categorical_crossentropy: 0.8275 - val_categorical_accuracy: 0.7885 - val_top_3_accuracy: 0.9153
# Epoch 49/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7803 - categorical_crossentropy: 0.7803 - categorical_accuracy: 0.7969 - top_3_accuracy: 0.9219 - val_loss: 0.8239 - val_categorical_crossentropy: 0.8239 - val_categorical_accuracy: 0.7902 - val_top_3_accuracy: 0.9156
# Epoch 50/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7801 - categorical_crossentropy: 0.7801 - categorical_accuracy: 0.7973 - top_3_accuracy: 0.9218 - val_loss: 0.8228 - val_categorical_crossentropy: 0.8228 - val_categorical_accuracy: 0.7902 - val_top_3_accuracy: 0.9167
# Epoch 51/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7740 - categorical_crossentropy: 0.7740 - categorical_accuracy: 0.7985 - top_3_accuracy: 0.9224 - val_loss: 0.8217 - val_categorical_crossentropy: 0.8217 - val_categorical_accuracy: 0.7894 - val_top_3_accuracy: 0.9171
# Epoch 52/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7815 - categorical_crossentropy: 0.7815 - categorical_accuracy: 0.7967 - top_3_accuracy: 0.9217 - val_loss: 0.8228 - val_categorical_crossentropy: 0.8228 - val_categorical_accuracy: 0.7895 - val_top_3_accuracy: 0.9171
# Epoch 53/70
# 800/800 [==============================] - 145s 181ms/step - loss: 0.7671 - categorical_crossentropy: 0.7671 - categorical_accuracy: 0.7995 - top_3_accuracy: 0.9237 - val_loss: 0.8208 - val_categorical_crossentropy: 0.8208 - val_categorical_accuracy: 0.7898 - val_top_3_accuracy: 0.9170
# Epoch 54/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7773 - categorical_crossentropy: 0.7773 - categorical_accuracy: 0.7974 - top_3_accuracy: 0.9226
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.00015016935867606662.
# 800/800 [==============================] - 145s 181ms/step - loss: 0.7773 - categorical_crossentropy: 0.7773 - categorical_accuracy: 0.7974 - top_3_accuracy: 0.9226 - val_loss: 0.8212 - val_categorical_crossentropy: 0.8212 - val_categorical_accuracy: 0.7901 - val_top_3_accuracy: 0.9167
# Epoch 55/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7729 - categorical_crossentropy: 0.7729 - categorical_accuracy: 0.7978 - top_3_accuracy: 0.9225 - val_loss: 0.8158 - val_categorical_crossentropy: 0.8158 - val_categorical_accuracy: 0.7914 - val_top_3_accuracy: 0.9174
# Epoch 56/70
# 800/800 [==============================] - 145s 181ms/step - loss: 0.7631 - categorical_crossentropy: 0.7631 - categorical_accuracy: 0.8006 - top_3_accuracy: 0.9241 - val_loss: 0.8163 - val_categorical_crossentropy: 0.8163 - val_categorical_accuracy: 0.7911 - val_top_3_accuracy: 0.9172
# Epoch 57/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7386 - categorical_crossentropy: 0.7386 - categorical_accuracy: 0.8068 - top_3_accuracy: 0.9266
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00011262702173553407.
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7386 - categorical_crossentropy: 0.7386 - categorical_accuracy: 0.8068 - top_3_accuracy: 0.9266 - val_loss: 0.8157 - val_categorical_crossentropy: 0.8157 - val_categorical_accuracy: 0.7924 - val_top_3_accuracy: 0.9177
# Epoch 58/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7354 - categorical_crossentropy: 0.7354 - categorical_accuracy: 0.8077 - top_3_accuracy: 0.9273 - val_loss: 0.8138 - val_categorical_crossentropy: 0.8138 - val_categorical_accuracy: 0.7918 - val_top_3_accuracy: 0.9178
# Epoch 59/70
# 800/800 [==============================] - 145s 181ms/step - loss: 0.7391 - categorical_crossentropy: 0.7391 - categorical_accuracy: 0.8072 - top_3_accuracy: 0.9269 - val_loss: 0.8139 - val_categorical_crossentropy: 0.8139 - val_categorical_accuracy: 0.7922 - val_top_3_accuracy: 0.9177
# Epoch 60/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7315 - categorical_crossentropy: 0.7315 - categorical_accuracy: 0.8084 - top_3_accuracy: 0.9280 - val_loss: 0.8134 - val_categorical_crossentropy: 0.8134 - val_categorical_accuracy: 0.7916 - val_top_3_accuracy: 0.9184
# Epoch 61/70
# 800/800 [==============================] - 147s 184ms/step - loss: 0.7507 - categorical_crossentropy: 0.7507 - categorical_accuracy: 0.8037 - top_3_accuracy: 0.9253 - val_loss: 0.8135 - val_categorical_crossentropy: 0.8135 - val_categorical_accuracy: 0.7916 - val_top_3_accuracy: 0.9181
# Epoch 62/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7297 - categorical_crossentropy: 0.7297 - categorical_accuracy: 0.8090 - top_3_accuracy: 0.9280 - val_loss: 0.8122 - val_categorical_crossentropy: 0.8122 - val_categorical_accuracy: 0.7930 - val_top_3_accuracy: 0.9181
# Epoch 63/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7348 - categorical_crossentropy: 0.7348 - categorical_accuracy: 0.8078 - top_3_accuracy: 0.9275
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 8.447026630165055e-05.
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7349 - categorical_crossentropy: 0.7349 - categorical_accuracy: 0.8077 - top_3_accuracy: 0.9275 - val_loss: 0.8142 - val_categorical_crossentropy: 0.8142 - val_categorical_accuracy: 0.7934 - val_top_3_accuracy: 0.9182
# Epoch 64/70
# 800/800 [==============================] - 145s 181ms/step - loss: 0.7362 - categorical_crossentropy: 0.7362 - categorical_accuracy: 0.8072 - top_3_accuracy: 0.9272 - val_loss: 0.8115 - val_categorical_crossentropy: 0.8115 - val_categorical_accuracy: 0.7939 - val_top_3_accuracy: 0.9185
# Epoch 65/70
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7274 - categorical_crossentropy: 0.7274 - categorical_accuracy: 0.8099 - top_3_accuracy: 0.9281 - val_loss: 0.8126 - val_categorical_crossentropy: 0.8126 - val_categorical_accuracy: 0.7930 - val_top_3_accuracy: 0.9185
# Epoch 66/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7349 - categorical_crossentropy: 0.7349 - categorical_accuracy: 0.8086 - top_3_accuracy: 0.9275
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 6.335269972623792e-05.
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7349 - categorical_crossentropy: 0.7349 - categorical_accuracy: 0.8086 - top_3_accuracy: 0.9275 - val_loss: 0.8114 - val_categorical_crossentropy: 0.8114 - val_categorical_accuracy: 0.7936 - val_top_3_accuracy: 0.9185
# Epoch 67/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7318 - categorical_crossentropy: 0.7318 - categorical_accuracy: 0.8086 - top_3_accuracy: 0.9280 - val_loss: 0.8103 - val_categorical_crossentropy: 0.8103 - val_categorical_accuracy: 0.7941 - val_top_3_accuracy: 0.9184
# Epoch 68/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7304 - categorical_crossentropy: 0.7304 - categorical_accuracy: 0.8091 - top_3_accuracy: 0.9277 - val_loss: 0.8106 - val_categorical_crossentropy: 0.8106 - val_categorical_accuracy: 0.7937 - val_top_3_accuracy: 0.9180
# Epoch 69/70
# 799/800 [============================>.] - ETA: 0s - loss: 0.7391 - categorical_crossentropy: 0.7391 - categorical_accuracy: 0.8069 - top_3_accuracy: 0.9269
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 4.751452615892049e-05.
# 800/800 [==============================] - 145s 182ms/step - loss: 0.7391 - categorical_crossentropy: 0.7391 - categorical_accuracy: 0.8069 - top_3_accuracy: 0.9269 - val_loss: 0.8102 - val_categorical_crossentropy: 0.8102 - val_categorical_accuracy: 0.7940 - val_top_3_accuracy: 0.9184
# Epoch 70/70
# 800/800 [==============================] - 146s 182ms/step - loss: 0.7334 - categorical_crossentropy: 0.7334 - categorical_accuracy: 0.8080 - top_3_accuracy: 0.9273 - val_loss: 0.8094 - val_categorical_crossentropy: 0.8094 - val_categorical_accuracy: 0.7947 - val_top_3_accuracy: 0.9185

# %%
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)
fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_categorical_accuracy, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.categorical_accuracy, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_categorical_crossentropy, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.categorical_crossentropy, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
fig.savefig('hist.png', dpi=300)
plt.show();

# %%
valid_predictions = model.predict(x_valid, batch_size=128, verbose=1)
map3 = mapk(valid_df[['y']].values, preds2catids(valid_predictions).values)
print('Map3: {:.3f}'.format(map3))
# Out:
# 34000/34000 [==============================] - 3s 101us/step
# Map3: 0.849

# %%
from PIL import Image, ImageOps 
from numpy import asarray

def predict_image(file_path):
    img = Image.open(file_path)
    img = ImageOps.invert(img)
    img = ImageOps.grayscale(img)

    numpydata = asarray(img)
    
    img_data = []
    for i in range(len(numpydata)):
        arr_to_append = [[x / 127.5 - 1] for x in numpydata[i]]
        img_data.append(arr_to_append)
        
    img_data = np.array([img_data])
    
    test_predictions = model.predict(img_data)

    top3 = preds2catids(test_predictions)

    cats = list_all_categories()
    id2cat = {k: cat.replace(' ', '_') for k, cat in enumerate(cats)}
    top3cats = top3.replace(id2cat)
    
    return top3cats['a'][0]
